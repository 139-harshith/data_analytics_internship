# %%
from textblob import TextBlob

df.columns = df.columns.str.strip()

def get_sentiment(text):
    return TextBlob(str(text)).sentiment.polarity

df['Sentiment'] = df['News'].apply(get_sentiment)

df['Label'] = df['Sentiment'].apply(
    lambda x: 'Positive' if x > 0 else 'Negative'
)

print(df['Label'].value_counts())
# Out:
# Label
# Positive    6
# Negative    4
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("datasetsnews.csv")

print(df.head())
print(df.shape)
# Out:
#                                             News
# 0     Stock market is performing very well today
# 1        Investors are happy with company growth
# 2         Company faces huge losses this quarter
# 3            Market crashes due to global issues
# 4  Strong performance boosts investor confidence
# (10, 1)

# %%
import matplotlib.pyplot as plt

df['Label'].value_counts().plot(kind='bar')
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
